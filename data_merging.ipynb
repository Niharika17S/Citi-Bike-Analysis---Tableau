# %%
import pandas as pd

# %%
df_201801 = "Resources/201801_tripdata.csv"
df1_201801 = pd.read_csv(df_201801)
len(df1_201801)
# Out:
# 718994

# %%
df_201802 = "Resources/201802_tripdata.csv"
df2_201802 = pd.read_csv(df_201802)
len(df2_201802)
# Out:
# 843114

# %%
df_201803 = "Resources/201803_tripdata.csv"
df3_201803 = pd.read_csv(df_201803)
len(df3_201803)
# Out:
# 976672

# %%
df_201804 = "Resources/201804_tripdata.csv"
df4_201804 = pd.read_csv(df_201804)
len(df4_201804)
# Out:
# 1307543

# %%
df_201805 = "Resources/201805_tripdata.csv"
df5_201805 = pd.read_csv(df_201805)
len(df5_201805)
# Out:
# 1824710

# %%
df_201806 = "Resources/201806_tripdata.csv"
df6_201806 = pd.read_csv(df_201806)
len(df6_201806)
# Out:
# 1953103

# %%
df_201807 = "Resources/201807_tripdata.csv"
df7_201807 = pd.read_csv(df_201807)
len(df7_201807)
# Out:
# 1913625

# %%
df_201808 = "Resources/201808_tripdata.csv"
df8_201808 = pd.read_csv(df_201808)
len(df8_201808)
# Out:
# 44432

# %%
df_201809 = "Resources/201809_tripdata.csv"
df9_201809 = pd.read_csv(df_201809)
len(df9_201809)
# Out:
# 39022

# %%
df_201810 = "Resources/201810_tripdata.csv"
df10_201810 = pd.read_csv(df_201810)
len(df10_201810)
# Out:
# 39138

# %%
df_201811 = "Resources/201811_tripdata.csv"
df11_201811 = pd.read_csv(df_201811)
len(df11_201811)
# Out:
# 24910

# %%
bikedata_201810 = "201810_tripdata.csv"
# df = pd.read_csv(bikedata_2018)
bikedata_201810_df = pd.read_csv(bikedata_201810)
len(bikedata_201810_df)
# bikedata_201810_df.head()
# Out:
# 39138

# %%
bikedata_201811 = "201811_tripdata.csv"
# df = pd.read_csv(bikedata_2018)
bikedata_201811_df = pd.read_csv(bikedata_201811)
len(bikedata_201811_df)
# bikedata_201811_df.count()
# Out:
# 24910

# %%
bikedata_201812 = "201812_tripdata.csv"
# df = pd.read_csv(bikedata_201812)
bikedata_201812_df = pd.read_csv(bikedata_201812)
len(bikedata_201812_df)
bikedata_201812_df.head(2)
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           170  2018-12-01 00:03:53.3860  2018-12-01 00:06:43.7160
# 1           172  2018-12-01 00:47:13.7340  2018-12-01 00:50:05.8160
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3214  Essex Light Rail
# 1               -74.033459            3481           York St
#
#    end station latitude  end station longitude  bikeid    usertype  \
# 0             40.712774             -74.036486   26261  Subscriber
# 1             40.716490             -74.041050   26175  Subscriber
#
#    birth year  gender
# 0        1975       1
# 1        1988       1

# %%
bikedata_201712 = "201712_bikedata.csv"
bikedata_201712_df = pd.read_csv(bikedata_201712)
len(bikedata_201712_df)
# bikedata_201712_df['Age'] = 2017 - bikedata_201712_df['birth year'];
# bikedata_201712_df.head(2)
# Out:
# 15898

# %% [markdown]
# # summer and winter datasets

# %%
summer_data = pd.concat([df5_201805,df6_201806,
                        df7_201807])
len(summer_data)
# Out:
# 5691438

# %%
summer_data.to_csv('summer_data.csv', sep = ',')

# %%
winter_data = pd.concat([bikedata_201712_df,df1_201801,df2_201802])
len(winter_data)
# Out:
# 1578006

# %%
winter_data.to_csv('winter_data.csv', sep = ',')

# %% [markdown]
# # combined data from dec2017 to dec2018

# %%
# combine bike data from dec 2017 to dec 2018
data_2018=pd.concat([df1_201801,df2_201802,df3_201803,df4_201804,df5_201805,df6_201806,
                        df7_201807,df8_201808,df9_201809,df10_201810,df11_201811,bikedata_201812_df])
len(data_2018)
# Out:
# 9705468

# %%
data_2018.head()

# %%
data_2018['Age'] = 2018 - data_2018['birth year'];
data_2018
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1               723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2               496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3               306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4               306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
# 5              1602  2018-01-01 21:31:54.1920  2018-01-01 21:58:36.3530
# 6               722  2018-01-02 07:54:53.6460  2018-01-02 08:06:55.8720
# 7               434  2018-01-02 08:06:14.3310  2018-01-02 08:13:28.7670
# 8               366  2018-01-02 08:10:15.2550  2018-01-02 08:16:21.8960
# 9               324  2018-01-02 08:13:30.8960  2018-01-02 08:18:55.1200
# 10             1155  2018-01-02 09:15:29.9050  2018-01-02 09:34:45.0200
# 11             1200  2018-01-02 10:23:18.8800  2018-01-02 10:43:18.9110
# ...

# %%
data_2018_17 = pd.concat([bikedata_201712_df,data_2018])
len(data_2018_17)
# Out:
# 9721366

# %%
data_2018_17.head(2)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           452  2017-12-01 00:00:59  2017-12-01 00:08:32              3183
# 1           159  2017-12-01 00:04:42  2017-12-01 00:07:21              3187
#
#   start station name  start station latitude  start station longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1          Warren St               40.721124               -74.038051
#
#    end station id end station name  end station latitude  \
# 0            3199     Newport Pkwy             40.728745
# 1            3186    Grove St PATH             40.719586
#
#    end station longitude  bikeid    usertype  birth year  gender   Age
# 0             -74.032108   29607  Subscriber      1988.0       1  29.0
# 1             -74.043117   26269  Subscriber      1992.0       1  25.0

# %%
data_2018_17.to_csv('data_2017_18.csv', sep = ',')

# %% [markdown]
# # Groupby on station name

# %%
bikedata_201712_df1=bikedata_201712_df.loc[bikedata_201712_df['start station name']=='Hamilton Park']
bikedata_201712_df1.loc[bikedata_201712_df1['end station name']=='5 Corners Library']
# Out:
#        tripduration            starttime             stoptime  \
# 951             763  2017-12-01 21:34:40  2017-12-01 21:47:24
# 2997            811  2017-12-04 20:49:16  2017-12-04 21:02:47
# 13536          1008  2017-12-22 15:21:07  2017-12-22 15:37:56
#
#        start station id start station name  start station latitude  \
# 951                3203      Hamilton Park               40.727596
# 2997               3203      Hamilton Park               40.727596
# 13536              3203      Hamilton Park               40.727596
#
#        start station longitude  end station id   end station name  \
# 951                 -74.044247            3220  5 Corners Library
# 2997                -74.044247            3220  5 Corners Library
# 13536               -74.044247            3220  5 Corners Library
#
#        end station latitude  end station longitude  bikeid    usertype  \
# 951               40.734961             -74.059503   31903  Subscriber
# ...

# %%
trips17_df = bikedata_201712_df.groupby(['start station name','end station name']).size().reset_index(name = 'Number of Trips')
# print(trips17_df[trips17_df['start station name']=='Hamilton Park']['Number of Trips'])
trips17_df.loc[trips17_df['start station name']=='Hamilton Park']
# Out:
#     start station name       end station name  Number of Trips
# 397      Hamilton Park      5 Corners Library                3
# 398      Hamilton Park  Baldwin at Montgomery                1
# 399      Hamilton Park        Brunswick & 6th                7
# 400      Hamilton Park           Brunswick St                3
# 401      Hamilton Park        Christ Hospital                1
# 402      Hamilton Park              City Hall               30
# 403      Hamilton Park         Columbus Drive               11
# 404      Hamilton Park            Dixon Mills                6
# 405      Hamilton Park       Essex Light Rail                9
# 406      Hamilton Park         Exchange Place               39
# 407      Hamilton Park          Grove St PATH              560
# 408      Hamilton Park          Hamilton Park               42
# 409      Hamilton Park             Harborside               47
# 410      Hamilton Park       Heights Elevator                2
# ...

# %%
# data for dec 2017 and dec 2018
newdata_2018_17=pd.concat([bikedata_201812_df, bikedata_201712_df])

# %%
# combine bike data from dec 2017 to dec 2018
data_2018_17=pd.concat([bikedata_201712_df,df1_201801,df2_201802,df3_201803,df4_201804,df5_201805,df6_201806,
                        df7_201807,df8_201808,df9_201809,df10_201810,df11_201811,bikedata_201812_df])

# %%
newdata_2018_17.tail()
# Out:
#        tripduration            starttime             stoptime  \
# 15893           972  2017-12-31 21:54:12  2017-12-31 22:10:25
# 15894           382  2017-12-31 22:10:18  2017-12-31 22:16:41
# 15895            93  2017-12-31 22:55:10  2017-12-31 22:56:43
# 15896           186  2017-12-31 23:20:54  2017-12-31 23:24:00
# 15897           422  2017-12-31 23:33:55  2017-12-31 23:40:57
#
#        start station id start station name  start station latitude  \
# 15893              3191           Union St               40.718211
# 15894              3280        Astor Place               40.719282
# 15895              3186      Grove St PATH               40.719586
# 15896              3270    Jersey & 6th St               40.725289
# 15897              3195            Sip Ave               40.730743
#
#        start station longitude  end station id end station name  \
# 15893               -74.083639            3186    Grove St PATH
# ...

# %%
newdata_2018_17.to_csv('newdata_2018_17.csv', sep = ',')

# %%
trips_df = newdata_2018_17.groupby(['start station name','end station name']).size().reset_index(name = 'Number of Trips')
trips_df.loc[trips_df['start station name']=='Hamilton Park']
# Out:
#     start station name       end station name  Number of Trips
# 598      Hamilton Park      5 Corners Library                4
# 599      Hamilton Park  Baldwin at Montgomery                1
# 600      Hamilton Park        Brunswick & 6th               14
# 601      Hamilton Park           Brunswick St               28
# 602      Hamilton Park        Christ Hospital                2
# 603      Hamilton Park              City Hall               66
# 604      Hamilton Park         Columbus Drive               25
# 605      Hamilton Park            Dixon Mills                7
# 606      Hamilton Park       Essex Light Rail               11
# 607      Hamilton Park         Exchange Place               56
# 608      Hamilton Park               Grand St               10
# 609      Hamilton Park          Grove St PATH             1034
# 610      Hamilton Park          Hamilton Park               69
# 611      Hamilton Park             Harborside              101
# ...

# %%
trips_df_sort = trips_df.sort_values(["Number of Trips"], ascending=False)
trips_df_sort.head(2)
# Out:
#     start station name end station name  Number of Trips
# 609      Hamilton Park    Grove St PATH             1034
# 567      Grove St PATH    Hamilton Park              699

# %%
trips_df_sort['Route'] = trips_df_sort['start station name']+ " to " + trips_df_sort['end station name']
trips_df_sort
# Out:
#            start station name       end station name  Number of Trips  \
# 609             Hamilton Park          Grove St PATH             1034
# 567             Grove St PATH          Hamilton Park              699
# 1194             Morris Canal         Exchange Place              539
# 834           Jersey & 6th St          Grove St PATH              509
# 464            Exchange Place           Morris Canal              472
# 141           Brunswick & 6th          Grove St PATH              449
# 382               Dixon Mills          Grove St PATH              411
# 1128         Monmouth and 6th          Grove St PATH              405
# 179              Brunswick St          Grove St PATH              397
# 560             Grove St PATH            Dixon Mills              389
# 1111          McGinley Square                Sip Ave              384
# 1515                  Sip Ave        McGinley Square              381
# ...

# %%
trips_df_sort.to_csv('Popular_Trips_df.csv', sep = ',')
